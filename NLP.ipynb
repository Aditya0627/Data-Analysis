# %%
import pandas as pd
import numpy as np

# %%
ds = pd.read_csv('output.csv')

# %%
ds
# Out:
#                  title  rating  \
# 0    Francesca Carioti     5.0
# 1          Helen Zhang     NaN
# 2           Mark Aduol     3.0
# 3     Ola Sidorkiewicz     NaN
# 4      Farrel Adhitama     5.0
# ..                 ...     ...
# 341          Doris Tai     5.0
# 342    Catarina Santos     5.0
# 343        Yiyuan Chen     NaN
# 344        Orianne CAO     5.0
# 345     Helena Gatland     NaN
#
#                                                   body
# 0    I have been using LOVESPACE during my three ye...
# 1    DON'T USE IT, THE WORST STORAGE COMPANY!!!\n\n...
# 2    Drivers are professional and make the collecti...
# 3    I left a box of my belongings with LOVESPACE o...
# 4    Jaye has deliver my boxes safe and sound.\nOve...
# ..                                                 ...
# 341                                                NaN
# 342                                                NaN
# 343                                                NaN
# ...

# %%
dt = ds[ds['body'].notna()]

# %%
dr = dt[dt['rating']!=5]

# %%
dr

# %%
df = pd.read_csv('aadi.csv')

# %%
df = df.drop('Unnamed: 0', axis =1)

# %%
df['review_text'][0]
# Out:
# 'We have our pax wardrobes from July, no mesh baskets or drawers and not a sole at IKEA has a clue when we might get them. How can we not order them? How can IKEA not know when any will be in stock. Pathetic.'

# %%
df['review_headline'][0]
# Out:
# 'We have our pax wardrobes from July'

# %%
da = pd.read_csv('com.csv')

# %%
data = pd.read_csv('com.csv')

# %%
da
# Out:
#                  Name Location  \
# 0                 Rob       GB
# 1            Sabine L       GB
# 2          Imran Alvi       GB
# 3    Jonatan Karlsson       GB
# 4                 Ewa       GB
# ..                ...      ...
# 199              Jane       GB
# 200                 J       GB
# 201             Maria       GB
# 202         Thelma H.       GB
# 203             erika       GB
#
#                                              Complaint  \
# 0    Didn't give slot, Communication is poor, Prodi...
# 1                                       Missing parcel
# 2                  Miss communication and late service
# 3    Miss communication, Provide wrong parcel, late...
# 4            Communicaton is too bad and late delivery
# ..                                                 ...
# 199        Lack of communication, Reschueled many time
# 200                             Worst customer service
# 201  Lack of information, Worst customer problem, U...
# ...

# %%
complaints = da['Complaint'].tolist()

# %%
complaints
# Out:
# ["Didn't give slot, Communication is poor, Prodive wrong product, Make damage percel, Sudden charge",
#  'Missing parcel',
#  'Miss communication and late service',
#  'Miss communication, Provide wrong parcel, late service and also missing parcel',
#  'Communicaton is too bad and late delivery',
#  'Late delivery and betray with customer',
#  "Sudden charge,  damage product, couldn't get into my account",
#  'Lost customer parcel, worst commuication and service, also late delivery',
#  'Lost 1300 pound customer property and betray with customer',
#  'Late delivery and poor customer service',
#  'Lost customer percel',
#  'Horrible customer service and scam prices',
#  'Terrible delivery and handling and not worth the price',
#  "Didn't pack half of the parcel and steal parcel",
#  'bad collection system and damage parcel',
#  'Very very poor service. Highly unprofessional and very unreliable',
#  'Lost customer parcel, Managers are never available',
#  'Reshedule and steal parcel',
# ...

# %%
#list2 = []
str1 = 'lost' = 1
str2 = 'late' = 5
str3 = 'communication' = 4
str4 = 'service' = 4
str27 = 'miss' = 4
str5 = 'missing' = 1                                    # 1 = lost item or missing complaints
str6 = 'steal' = 6
str26 = 'stolen' = 6                                    #2 = item broken or damaged complaints
str7 = 'broken' = 2                                     #3 = item is costly or high charges related complaints
str8 = 'broke' = 2
str9 = 'costly' = 3                                     #4 = customer service problem
str10 = 'cost' = 3
str11 = 'charge' = 3                                    #5 = late or delayed delivery
str29 = 'charged' = 3
str30 = 'money' = 7                                     #6 = item stolen complain
                                                        #7 = money related complaints
str12 = 'customer service' = 4                          #8 = other type of complaints
str14 = 'charges' = 3                                   
str15 = 'expensive' = 3
str16 = 'damage' = 2
str17 = 'time' = 5
str18 = 'reply' = 4
str28 = 'replying' = 4
str19 = 'delayed' = 5
str20 = 'lost parcel' = 1
str21 = 'missing parcel' = 1
str22 = 'stolen parcel' = 6
str23 = 'broken parcel' = 2
str24 = 'damage parcel' = 2
str25 = 'delayed parcel' = 5
#str31 = 'worst'
#tr32 = 'experience'
#str33 = 'never'
#str34 = ''
# Out:
#   File "<ipython-input-11-57335c25fdba>", line 2
#     str1 = 'lost' = 1
#            ^
# SyntaxError: cannot assign to literal

# %%
for i in range(0,204):
    complaints[i] = complaints[i].lower()

# %%
list3 = complaints

# %%
len(list3)
# Out:
# 204

# %%
listp = []

# %%
len(listp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-372809b155fe> in <module>
# ----> 1 len(listp)
#
# NameError: name 'listp' is not defined

# %%
for i in range(0,204):
   
        if(list3[i].find(str1)!=-1):
            listp.append(1)
            
        elif(list3[i].find(str9)!=-1):
            listp.append(3)
            
        elif(list3[i].find(str7)!=-1):
            listp.append(2)
            
        elif(list3[i].find(str8)!=-1):
             listp.append(2)
            
            
        elif(list3[i].find(str5)!=-1):
            listp.append(1)
            
        elif(list3[i].find(str16)!=-1):
             listp.append(2)
            
            
        elif(list3[i].find(str10)!=-1):
            listp.append(3)
            
            
        elif(list3[i].find(str11)!=-1):
            listp.append(3)
            
            
        elif(list3[i].find(str14)!=-1):
            listp.append(3)
            
            
            
        elif(list3[i].find(str15)!=-1):
            listp.append(3)
        
        elif(list3[i].find(str3)!=-1):
            listp.append(4)
            
        elif(list3[i].find(str4)!=-1):
            listp.append(4)
            
        elif(list3[i].find(str12)!=-1):
            listp.append(4)
            
        elif(list3[i].find(str2)!=-1):
            listp.append(5)
            
        elif(list3[i].find(str17)!=-1):
            listp.append(5)
            
        elif(list3[i].find(str19)!=-1):
            listp.append(5)
        
        elif(complaints[i].find(str18)!=-1):
            listp.append(4)
            
        elif(list3[i].find(str6)!=-1):
            listp.append(6)
            
        elif(list3[i].find(str26)!=-1):
            listp.append(6)
            
        elif(list3[i].find(str27)!=-1):
            listp.append(4)
            
        elif(list3[i].find(str20)!=-1):
            listp.append(1)
        elif(list3[i].find(str21)!=-1):
            listp.append(1)
        elif(list3[i].find(str23)!=-1):
            listp.append(2)
        elif(list3[i].find(str24)!=-1):
            listp.append(2)
        elif(list3[i].find(str25)!=-1):
            listp.append(5)
        elif(list3[i].find(str22)!=-1):
            listp.append(6)
        elif(list3[i].find(str28)!=-1):
            listp.append(4)
        elif(list3[i].find(str29)!=-1):
            listp.append(3)
        elif(list3[i].find(str30)!=-1):
            listp.append(7)
        else:
            listp.append(0)

# %%
d1 = pd.DataFrame(listp)

# %%
d[0].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f513a71af822> in <module>
# ----> 1 d[0].value_counts()
#
# NameError: name 'd' is not defined

# %%
lis = []
for i in range(0,204):
    if(listp[i] == 1):
       lis.append('lost item or missing complaints')
       
    elif(listp[i] == 2):
         lis.append('item broken or damaged complaints')
    
    elif(listp[i] == 3):
         lis.append('item is costly or high charges related complaints')
         
    elif(listp[i] == 4):
         lis.append('customer service complaints')
    
    elif(listp[i] == 5):
         lis.append('late or delayed delivery')
         
    elif(listp[i] == 6):
         lis.append('item stolen complain')
         
    elif(listp[i] == 7):
         lis.append('money related complaints')
         
    elif(listp[i] == 0):
         lis.append('other services related complaints')

# %%
len(lis)

# %%
d1['keywords'] = lis

# %%
d1['Name'] = da['Name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-82d46b090977> in <module>
# ----> 1 d1['Name'] = da['Name']
#
# NameError: name 'd1' is not defined

# %%
d1

# %%
d2 = d1.drop(0, axis =1 )

# %%
d2.to_csv('keyword_compla.csv')

# %%
da['Full complaint'][0]
# Out:
# "We used Lovespace to collect and store items for 2 months when we sold our flat and was waiting to move into our new property. Unfortunately I can not recommend this company as they made lots of mistakes and caused us many issues and stress. They really were appalling.Firstly, we never received a collection time slot. We called them numerous times right up to the day before we were due to move out (Sunday) but all that we were told was that they hadn't allocated a vehicle or time yet, but we'd receive one before 6pm at the latest. This never happened and i was unable to call them again after waiting until 6pm as advised because they were shut.On the day we had to vacate the flat we had to call them first thing in the morning and we were told that  they had made an error and still had not allocated a time slot However, the person I spoke to did say that they would definitely get someone out on the day booked, which they did. However, although once again they said they would call with
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Lovespaces_Reviews (2).csv')

# Preprocessing the data
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#from nltk.corpus import stopwords
#from nltk.stem.porter import PorterStemmer
c = []
for i in range(0, 204):
    revie = re.sub('[^a-zA-Z]', ' ', dataset['Complaint'][i])
    revie = revie.lower()
    revie = revie.split() # Splitting the review into a list of words
    ps = PorterStemmer()
    revie = [ps.stem(word) for word in revie if not word in set(stopwords.words('english'))]
    revie = ' '.join(revie) # Joining the list of words
    c.append(revie)

# %%
c1 = []
for i in range(0, 204):
    revi = re.sub('[^a-zA-Z]', ' ', dataset['Full complaint'][i])
    revi = revi.lower()
    revi = revi.split() # Splitting the review into a list of words
    ps = PorterStemmer()
    revi = [ps.stem(word) for word in revi if not word in set(stopwords.words('english'))]
    revi = ' '.join(revi) # Joining the list of words
    c1.append(revi)

# %%
c1[0].count('time')
# Out:
# 13

# %%
type(data['Name'])
# Out:
# pandas.core.series.Series

# %%
c1
# Out:
# ['use lovespac collect store item month sold flat wait move new properti unfortun recommend compani made lot mistak caus us mani issu stress realli appal firstli never receiv collect time slot call numer time right day due move sunday told alloc vehicl time yet receiv one pm latest never happen unabl call wait pm advis shut day vacat flat call first thing morn told made error still alloc time slot howev person spoke say would definit get someon day book howev although said would call time collect turn unannounc issu regard timeslot collect call lovespac numer time get timeslot redeliveri unfortun mess also receiv timeslot custom servic advisor receiv email complet differ timeslot one initi provid call given yet anoth differ timeslot day redeliveri left stay chester get manchest long arriv receiv text messag state collect time chang men deliv item profession friendli found later caus damag expens mattress whilst move upstair sympathi genuin mistak guy turn actual realli good howev wen
# ...

# %%
data['Full complaint'][0].count('time')

# %%
from collections import Counter

# %%
from collections import Counter
  
data_set = c1[0]
# split() returns list of all the words in the string
split_it = data_set.split()
  
# Pass the split_it list to instance of Counter class.
Counter = Counter(split_it)
  
# most_common() produces k frequently encountered
# input values and their respective counts.
most_occur = Counter.most_common(4)
  
print(most_occur)
# Out:
# [('lovespac', 8), ('collect', 8), ('time', 8), ('call', 8)]

# %%
l = []
for i in range(0,204):
    str1 = c1[i]
    sp = str1.split()  
    obj =Counter(sp)
    m = obj.most_common(4)
    print(m)
#del obj
# Out:
# [('lovespac', 8), ('collect', 8), ('time', 8), ('call', 8)]
# [('box', 7), ('deliv', 4), ('inform', 4), ('one', 3)]
# [('pick', 2), ('day', 2), ('bad', 1), ('servic', 1)]
# [('box', 5), ('deliv', 3), ('item', 2), ('lovespac', 2)]
# [('day', 7), ('deliveri', 4), ('schedul', 3), ('stuff', 3)]
# [('custom', 2), ('servic', 2), ('box', 2), ('deliveri', 2)]
# [('box', 6), ('time', 5), ('tri', 4), ('schedul', 4)]
# [('call', 7), ('told', 6), ('wait', 5), ('come', 5)]
# [('box', 5), ('two', 4), ('never', 3), ('lovespac', 3)]
# [('custom', 2), ('unabl', 1), ('provid', 1), ('eta', 1)]
# [('claim', 3), ('space', 2), ('lost', 2), ('deliv', 2)]
# [('servic', 4), ('custom', 4), ('horribl', 2), ('scam', 2)]
# [('box', 7), ('deliveri', 4), ('open', 3), ('call', 3)]
# [('thing', 6), ('lovespac', 4), ('deliv', 4), ('pack', 3)]
# [('collect', 3), ('thing', 3), ('box', 3), ('would', 2)]
# [('parcel', 2), ('glasgow', 2), ('would', 2), ('take', 2)]
# [('servic', 2), ('use', 1), ('lost', 1), ('box', 1)]
# ...

# %%
'''obj =Counter(sp)
m = obj.most_common(4)
print(m)
del obj'''
# Out:
# [('to', 28), ('the', 22), ('I', 20), ('we', 19)]

# %%
li = [
[('lovespac', 8), ('collect', 8), ('time', 8), ('call', 8)],
[('box', 7), ('deliv', 4), ('inform', 4), ('one', 3)],
[('pick', 2), ('day', 2), ('bad', 1), ('servic', 1)],
[('box', 5), ('deliv', 3), ('item', 2), ('lovespac', 2)],
[('day', 7), ('deliveri', 4), ('schedul', 3), ('stuff', 3)],
[('custom', 2), ('servic', 2), ('box', 2), ('deliveri', 2)],
[('box', 6), ('time', 5), ('tri', 4), ('schedul', 4)],
[('call', 7), ('told', 6), ('wait', 5), ('come', 5)],
[('box', 5), ('two', 4), ('never', 3), ('lovespac', 3)],
[('custom', 2), ('unabl', 1), ('provid', 1), ('eta', 1)],
[('claim', 3), ('space', 2), ('lost', 2), ('deliv', 2)],
[('servic', 4), ('custom', 4), ('horribl', 2), ('scam', 2)],
[('box', 7), ('deliveri', 4), ('open', 3), ('call', 3)],
[('thing', 6), ('lovespac', 4), ('deliv', 4), ('pack', 3)],
[('collect', 3), ('thing', 3), ('box', 3), ('would', 2)],
[('parcel', 2), ('glasgow', 2), ('would', 2), ('take', 2)],
[('servic', 2), ('use', 1), ('lost', 1), ('box', 1)],
[('collect', 3), ('servic', 3), ('would', 3), ('cancel', 2)],
[('box', 6), ('compani', 3), ('kitchen', 3), ('three', 3)],
[('lovespac', 8), ('item', 7), ('find', 7), ('call', 6)],
[('deliveri', 5), ('item', 4), ('custom', 4), ('servic', 4)],
[('storag', 5), ('possess', 3), ('book', 2), ('collect', 2)],
[('call', 3), ('servic', 2), ('receiv', 2), ('websit', 2)],
[('ghost', 3), ('never', 2), ('made', 2), ('wrong', 2)],
[('delay', 2), ('mistak', 1), ('one', 1), ('order', 1)],
[('lovespac', 6), ('month', 6), ('servic', 5), ('store', 4)],
[('order', 2), ('sinc', 2), ('saturday', 2), ('contact', 2)],
[('month', 3), ('coordin', 2), ('sent', 2), ('lovespac', 1)],
[('box', 5), ('lovespac', 4), ('custom', 4), ('three', 3)],
[('charg', 2), ('money', 2), ('account', 2), ('month', 2)],
[('stuff', 3), ('could', 2), ('box', 2), ('person', 2)],
[('charg', 3), ('stop', 3), ('money', 3), ('card', 2)],
[('box', 8), ('happen', 3), ('call', 3), ('told', 3)],
[('box', 11), ('lovespac', 10), ('collect', 9), ('courier', 8)],
[('box', 3), ('return', 2), ('alreadi', 2), ('take', 2)],
[('pair', 5), ('love', 4), ('space', 4), ('pack', 4)],
[('lovespac', 8), ('box', 7), ('collect', 6), ('courier', 5)],
[('thing', 2), ('mani', 1), ('miss', 1), ('lot', 1)],
[('cost', 1), ('good', 1), ('websit', 1), ('clear', 1)],
[('pound', 2), ('guitar', 2), ('pay', 2), ('broke', 1)],
[('ask', 3), ('one', 3), ('long', 2), ('lovespac', 2)],
[('pack', 5), ('help', 3), ('lovespac', 3), ('one', 3)],
[('charg', 4), ('one', 3), ('payment', 3), ('would', 3)],
[('box', 14), ('driver', 9), ('call', 9), ('wait', 6)],
[('stuff', 6), ('pack', 6), ('even', 4), ('compani', 3)],
[('shirt', 4), ('storag', 3), ('sent', 3), ('got', 2)],
[('use', 2), ('servic', 2), ('paid', 2), ('initi', 2)],
[('servic', 4), ('stay', 2), ('away', 2), ('item', 2)],
[('deliveri', 5), ('lovespac', 5), ('even', 4), ('one', 3)],
[('would', 7), ('know', 6), ('product', 4), ('record', 4)],
[('th', 5), ('student', 3), ('collect', 3), ('earlier', 3)],
[('compani', 2), ('let', 2), ('know', 2), ('soon', 2)],
[('lovespac', 3), ('charg', 3), ('box', 3), ('compani', 2)],
[('back', 9), ('ask', 6), ('stuff', 5), ('end', 5)],
[('item', 9), ('student', 6), ('ship', 6), ('far', 5)],
[('get', 4), ('extra', 3), ('howev', 2), ('cost', 2)],
[('say', 3), ('email', 2), ('stuff', 2), ('use', 1)],
[('day', 3), ('terribl', 1), ('could', 1), ('advis', 1)],
[('day', 4), ('ship', 3), ('date', 3), ('charg', 3)],
[('month', 3), ('ship', 3), ('stuff', 2), ('lovespac', 2)],
[('seem', 2), ('still', 1), ('wait', 1), ('repli', 1)],
[('compani', 4), ('good', 3), ('servic', 3), ('use', 2)],
[('box', 12), ('stuff', 5), ('told', 5), ('ask', 5)],
[('lovespac', 7), ('stuff', 5), ('guernsey', 4), ('uni', 4)],
[('ship', 3), ('would', 2), ('stuff', 2), ('horribl', 1)],
[('compani', 4), ('custom', 4), ('servic', 4), ('box', 4)],
[('student', 6), ('use', 3), ('accomod', 3), ('deliveri', 3)],
[('stuff', 4), ('room', 4), ('lovespac', 3), ('repli', 3)],
[('pack', 3), ('servic', 2), ('room', 2), ('stuff', 2)],
[('pack', 8), ('pay', 6), ('order', 6), ('place', 5)],
[('servic', 3), ('recommend', 2), ('turn', 2), ('ever', 2)],
[('room', 4), ('contact', 2), ('collect', 2), ('joke', 1)],
[('email', 3), ('happen', 2), ('lovespac', 2), ('fast', 2)],
[('hidden', 2), ('charg', 2), ('horribl', 2), ('servic', 2)],
[('experi', 2), ('time', 2), ('would', 2), ('charg', 1)],
[('th', 6), ('arriv', 5), ('materi', 4), ('email', 4)],
[('lovespac', 7), ('immedi', 2), ('told', 2), ('accommod', 2)],
[('review', 3), ('bad', 2), ('got', 2), ('custom', 2)],
[('still', 2), ('charg', 1), ('credit', 1), ('card', 1)],
[('month', 3), ('refund', 3), ('abl', 2), ('time', 2)],
[('despit', 3), ('contract', 3), ('charg', 3), ('email', 2)],
[('non', 1), ('exist', 1), ('custom', 1), ('servic', 1)],
[('room', 3), ('us', 3), ('collect', 2), ('charg', 2)],
[('deliveri', 6), ('date', 4), ('march', 3), ('fail', 3)],
[('th', 14), ('receiv', 5), ('materi', 4), ('say', 4)],
[('collect', 6), ('contact', 3), ('reschedul', 3), ('number', 2)],
[('servic', 2), ('driver', 1), ('turn', 1), ('pick', 1)],
[('item', 4), ('charg', 4), ('collect', 3), ('email', 2)],
[('compani', 2), ('charg', 2), ('collect', 2), ('complet', 1)],
[('avoid', 2), ('compani', 2), ('aw', 1), ('servic', 1)],
[('box', 6), ('arriv', 4), ('fragil', 4), ('lot', 3)],
[('stupist', 1), ('system', 1), ('earth', 1), ('lie', 1)],
[('compani', 4), ('storag', 4), ('box', 4), ('email', 4)],
[('box', 4), ('chase', 4), ('ever', 3), ('repli', 3)],
[('time', 2), ('call', 1), ('text', 1), ('come', 1)],
[('deliveri', 4), ('call', 4), ('even', 3), ('box', 3)],
[('guitar', 7), ('day', 3), ('call', 3), ('locat', 3)],
[('item', 7), ('miss', 4), ('treat', 3), ('includ', 2)],
[('thing', 4), ('compani', 3), ('pleas', 2), ('stay', 2)],
[('use', 3), ('damag', 3), ('receiv', 2), ('thank', 2)],
[('refund', 4), ('box', 4), ('th', 4), ('still', 2)],
[('deliveri', 5), ('even', 3), ('first', 3), ('lovespac', 3)],
[('son', 2), ('lovespac', 2), ('item', 2), ('one', 2)],
[('box', 6), ('get', 4), ('day', 4), ('order', 3)],
[('stuff', 2), ('h', 2), ('call', 2), ('worst', 1)],
[('servic', 2), ('even', 1), ('explain', 1), ('bad', 1)],
[('box', 7), ('collect', 5), ('driver', 5), ('compani', 4)],
[('deliv', 3), ('bag', 2), ('locat', 2), ('parcel', 2)],
[('compani', 4), ('deliveri', 3), ('use', 2), ('return', 2)],
[('box', 9), ('deliveri', 7), ('lovespac', 6), ('pm', 6)],
[('stuff', 2), ('would', 1), ('give', 1), ('star', 1)],
[('box', 4), ('collect', 2), ('send', 2), ('terribl', 1)],
[('never', 2), ('custom', 2), ('servic', 2), ('week', 2)],
[('deliveri', 7), ('day', 3), ('call', 3), ('get', 3)],
[('box', 8), ('accommod', 3), ('deliv', 2), ('london', 2)]
,[('account', 2), ('updat', 2), ('terribl', 1), ('experi', 1)]
,[('box', 4), ('alway', 3), ('day', 2), ('still', 2)]
,[('order', 2), ('number', 2), ('collect', 1), ('return', 1)]
,[('deliveri', 12), ('never', 5), ('day', 4), ('would', 4)]
,[('like', 2), ('condit', 1), ('box', 1), ('return', 1)]
,[('box', 3), ('collect', 2), ('one', 2), ('broken', 2)]
,[('box', 4), ('receiv', 3), ('disappoint', 2), ('paid', 2)]
,[('stuff', 2), ('deliv', 2), ('today', 2), ('problem', 1)]
,[('get', 4), ('whole', 2), ('servic', 2), ('super', 2)]
,[('pm', 3), ('one', 2), ('pick', 2), ('day', 2)]
,[('box', 7), ('parcelforc', 5), ('call', 3), ('got', 3)]
,[('call', 3), ('number', 3), ('compani', 2), ('time', 2)]
,[('collect', 1), ('go', 1), ('well', 1), ('driver', 1)]
,[('return', 3), ('promis', 3), ('box', 2), ('monday', 2)]
,[('servic', 5), ('ever', 2), ('life', 2), ('lovespac', 1)]
,[('attempt', 5), ('number', 3), ('postcod', 3), ('deliveri', 3)]
,[('day', 6), ('box', 4), ('never', 2), ('receiv', 2)]
,[('day', 8), ('box', 7), ('call', 5), ('deliv', 5)]
,[('box', 5), ('lovespac', 2), ('receiv', 2), ('wrap', 2)]
,[('would', 3), ('th', 3), ('driver', 2), ('time', 2)]
,[('box', 4), ('charg', 2), ('pm', 2), ('worst', 1)]
,[('order', 5), ('box', 4), ('team', 4), ('arriv', 3)]
,[('item', 4), ('storag', 4), ('time', 3), ('advertis', 2)]
,[('box', 2), ('servic', 2), ('manag', 2), ('week', 1)]
,[('cancel', 4), ('order', 3), ('august', 2), ('still', 2)]
,[('box', 6), ('item', 4), ('lost', 3), ('lovespac', 3)]
,[('order', 5), ('thing', 4), ('move', 4), ('compani', 3)]
,[('collect', 4), ('driver', 4), ('box', 3), ('organis', 2)]
,[('call', 3), ('driver', 3), ('pickup', 3), ('collect', 2)]
,[('box', 4), ('item', 3), ('time', 2), ('return', 2)]
,[('box', 3), ('would', 2), ('th', 2), ('deliv', 2)]
,[('box', 2), ('super', 1), ('disappoint', 1), ('mess', 1)]
,[('collect', 2), ('extrem', 1), ('disappoint', 1), ('lovespac', 1)]
,[('collect', 3), ('day', 3), ('suck', 1), ('servicei', 1)]
,[('websit', 2), ('servic', 2), ('terribl', 1), ('function', 1)]
,[('wait', 6), ('driver', 5), ('time', 4), ('parcel', 3)]
,[('furnitur', 5), ('websit', 3), ('select', 2), ('item', 2)]
,[('poor', 1), ('system', 1), ('nearli', 1), ('charg', 1)]
,[('lost', 3), ('thing', 3), ('one', 2), ('luggag', 2)]
,[('well', 3), ('compani', 2), ('crush', 2), ('even', 2)]
,[('box', 4), ('week', 4), ('told', 3), ('compani', 2)]
,[('box', 7), ('even', 4), ('els', 4), ('would', 4)]
,[('box', 3), ('one', 2), ('everi', 2), ('got', 2)]
,[('box', 7), ('call', 5), ('know', 5), ('arriv', 4)]
,[('call', 4), ('lovespac', 3), ('never', 3), ('return', 2)]
,[('lovespac', 7), ('address', 5), ('servic', 4), ('sent', 4)]
,[('deliveri', 10), ('day', 8), ('intern', 4), ('call', 4)]
,[('custom', 2), ('support', 2), ('friendli', 2), ('take', 1)]
,[('wait', 2), ('box', 1), ('open', 1), ('friend', 1)]
,[('one', 3), ('give', 2), ('servic', 2), ('appoint', 2)]
,[('box', 5), ('never', 2), ('got', 2), ('like', 2)]
,[('use', 6), ('box', 6), ('lovespac', 4), ('say', 3)]
,[('box', 9), ('lovespac', 7), ('good', 5), ('return', 5)]
,[('end', 3), ('use', 2), ('servic', 2), ('bag', 2)]
,[('refund', 6), ('charg', 5), ('book', 4), ('lovespac', 4)]
,[('keyboard', 4), ('said', 3), ('lost', 2), ('month', 2)]
,[('box', 5), ('call', 5), ('lovespac', 5), ('ask', 5)]
,[('box', 7), ('lovespac', 5), ('label', 3), ('back', 3)]
,[('deliveri', 4), ('got', 4), ('box', 4), ('stuff', 3)]
,[('box', 15), ('order', 5), ('repli', 5), ('id', 5)]
,[('contact', 2), ('delay', 1), ('collect', 1), ('item', 1)]
,[('lovespac', 2), ('return', 2), ('custom', 2), ('item', 2)]
,[('box', 10), ('damag', 5), ('deliv', 3), ('week', 3)]
,[('use', 4), ('compani', 3), ('absolut', 2), ('love', 2)]
,[('materi', 5), ('door', 5), ('tuesday', 4), ('get', 4)]
,[('lovespac', 12), ('box', 9), ('cost', 6), ('custom', 5)]
,[('pack', 3), ('materi', 3), ('book', 3), ('collect', 3)]
,[('box', 4), ('lovespac', 4), ('miss', 3), ('call', 3)]
,[('compani', 4), ('box', 3), ('call', 3), ('lost', 2)]
,[('item', 4), ('need', 2), ('back', 2), ('order', 2)]
,[('box', 3), ('line', 3), ('sept', 2), ('lovespac', 2)]
,[('car', 2), ('seat', 2), ('mothercar', 2), ('lovespac', 2)]
,[('box', 9), ('would', 6), ('one', 4), ('even', 4)]
,[('call', 6), ('box', 4), ('receiv', 3), ('pm', 3)]
,[('two', 3), ('one', 2), ('experi', 2), ('regard', 2)]
,[('custom', 4), ('lovespac', 3), ('idea', 2), ('storag', 2)]
,[('box', 9), ('day', 5), ('email', 3), ('say', 3)]
,[('box', 6), ('one', 4), ('answer', 3), ('promis', 2)]
,[('get', 2), ('th', 1), ('day', 1), ('item', 1)]
,[('student', 2), ('use', 2), ('insur', 2), ('two', 2)]
,[('collect', 6), ('would', 6), ('email', 5), ('refund', 5)]
,[('box', 2), ('st', 2), ('floor', 2), ('store', 1)]
,[('tell', 2), ('despit', 1), ('love', 1), ('attract', 1)]
,[('deliveri', 4), ('box', 2), ('sever', 1), ('damag', 1)]
,[('team', 3), ('great', 2), ('commun', 2), ('member', 2)]
,[('receiv', 3), ('email', 3), ('call', 3), ('timeslot', 3)]
,[('servic', 4), ('collect', 3), ('would', 2), ('recommend', 2)]
,[('miss', 3), ('box', 3), ('item', 2), ('lovespac', 2)]
,[('return', 3), ('item', 2), ('week', 2), ('two', 2)]]

# %%
for i in range(0,1):
    l = li[i]

# %%
c = pd.read_csv('keyword_compla.csv')

# %%
c['key from full'] = li

# %%
c['key from full']
# Out:
# 0      [(lovespac, 8), (collect, 8), (time, 8), (call...
# 1          [(box, 7), (deliv, 4), (inform, 4), (one, 3)]
# 2           [(pick, 2), (day, 2), (bad, 1), (servic, 1)]
# 3       [(box, 5), (deliv, 3), (item, 2), (lovespac, 2)]
# 4      [(day, 7), (deliveri, 4), (schedul, 3), (stuff...
#                              ...
# 199    [(team, 3), (great, 2), (commun, 2), (member, 2)]
# 200    [(receiv, 3), (email, 3), (call, 3), (timeslot...
# 201    [(servic, 4), (collect, 3), (would, 2), (recom...
# 202      [(miss, 3), (box, 3), (item, 2), (lovespac, 2)]
# 203        [(return, 3), (item, 2), (week, 2), (two, 2)]
# Name: key from full, Length: 204, dtype: object

# %%
c.to_csv('keyword_compla.csv')

# %%
di ={}

# %%
for i in range(0,1):
    di.keys =
